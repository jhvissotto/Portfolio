# %%
# !pip install ffn

# %%
import ffn

# %% [markdown]
# # Data

# %%
data = ffn.get('MSFT,SPY', start='2010-01-01')
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  msft        spy
# Date
# 2010-01-04  23.300682  86.026482
# 2010-01-05  23.308205  86.254173
# 2010-01-06  23.165167  86.314896
# 2010-01-07  22.924257  86.679253
# 2010-01-08  23.082354  86.967720

# %% [markdown]
# # Calculations

# %%
data.calc_stats().display()
# Out:
# Stat                 msft        spy
# -------------------  ----------  ----------
# Start                2010-01-04  2010-01-04
# End                  2025-02-21  2025-02-21
# Risk-free rate       0.00%       0.00%
#
# Total Return         1651.92%    597.39%
# Daily Sharpe         0.87        0.84
# Daily Sortino        1.45        1.31
# CAGR                 20.83%      13.69%
# Max Drawdown         -37.15%     -33.72%
# Calmar Ratio         0.56        0.41
#
# MTD                  -1.65%      -0.31%
# 3m                   -1.13%      1.40%
# 6m                   -3.56%      7.70%
# YTD                  -3.15%      2.36%
# 1Y                   2.07%       22.21%
# 3Y (ann.)            13.26%      13.44%
# 5Y (ann.)            18.96%      14.17%
# 10Y (ann.)           26.75%      12.96%
# Since Incep. (ann.)  20.83%      13.69%
#
# Daily Sharpe         0.87        0.84
# Daily Sortino        1.45        1.31
# Daily Mean (ann.)    22.23%      14.31%
# ...

# %% [markdown]
# # Historical Performance

# %%
data.rebase().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Drawdown

# %%
data.to_drawdown_series().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Volatility Histogram

# %%
data.to_returns().dropna().hist()
# Out:
# array([[<Axes: title={'center': 'msft'}>,
#         <Axes: title={'center': 'spy'}>]], dtype=object)
